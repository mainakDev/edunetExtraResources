# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/kaggle/input/palmer-penguins-for-binary-classification/penguins_binary_classification.csv')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g  year
# 0       3750.0  2007
# 1       3800.0  2007
# 2       3250.0  2007
# 3       3450.0  2007
# 4       3650.0  2007

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            274 non-null    object
#  1   island             274 non-null    object
#  2   bill_length_mm     274 non-null    float64
#  3   bill_depth_mm      274 non-null    float64
#  4   flipper_length_mm  274 non-null    float64
#  5   body_mass_g        274 non-null    float64
#  6   year               274 non-null    int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 15.1+ KB

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# year                 0
# dtype: int64

# %%
df.nunique()
# Out:
# species                2
# island                 3
# bill_length_mm       146
# bill_depth_mm         78
# flipper_length_mm     54
# body_mass_g           89
# year                   3
# dtype: int64

# %%
sns.pairplot(data = df,hue='species')

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

df['species'] = encoder.fit_transform(df['species'])
df['island'] = encoder.fit_transform(df['island'])
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'year'],
#       dtype='object')

# %%
df.head()
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0        0       2            39.1           18.7              181.0
# 1        0       2            39.5           17.4              186.0
# 2        0       2            40.3           18.0              195.0
# 3        0       2            36.7           19.3              193.0
# 4        0       2            39.3           20.6              190.0
#
#    body_mass_g  year
# 0       3750.0  2007
# 1       3800.0  2007
# 2       3250.0  2007
# 3       3450.0  2007
# 4       3650.0  2007

# %%
X = df[['island', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'year']]
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=42)

# %%
X_train.head()
# Out:
#      island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 177       0            44.5           14.3              216.0       4100.0
# 248       0            46.9           14.6              222.0       4875.0
# 74        2            42.8           18.5              195.0       4250.0
# 170       0            48.7           15.1              222.0       5350.0
# 29        1            39.5           16.7              178.0       3250.0
#
#      year
# 177  2007
# 248  2009
# 74   2008
# 170  2007
# 29   2007

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm = LogisticRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=pd.DataFrame(sc.fit_transform(X_train))
X_test=pd.DataFrame(sc.transform(X_test))
X_train.head()
# Out:
#           0         1         2         3         4         5
# 0 -0.697564  0.341080 -1.260795  0.904032 -0.269445 -1.260997
# 1 -0.697564  0.807547 -1.110599  1.307098  0.688497  1.215692
# 2  1.932333  0.010666  0.841955 -0.506700 -0.084037 -0.022653
# 3 -0.697564  1.157398 -0.860272  1.307098  1.275622 -1.260997
# 4  0.617384 -0.630726 -0.059224 -1.648722 -1.320090 -1.260997

# %%
X_train.columns= X.columns   
X_test.columns= X.columns

y_train.index= X_train.index
y_test.index= X_test.index

X_train.head()
# Out:
#      island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0 -0.697564        0.341080      -1.260795           0.904032    -0.269445
# 1 -0.697564        0.807547      -1.110599           1.307098     0.688497
# 2  1.932333        0.010666       0.841955          -0.506700    -0.084037
# 3 -0.697564        1.157398      -0.860272           1.307098     1.275622
# 4  0.617384       -0.630726      -0.059224          -1.648722    -1.320090
#
#        year
# 0 -1.260997
# 1  1.215692
# 2 -0.022653
# 3 -1.260997
# 4 -1.260997

# %%
predictions = lm.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix

print('Classification report',classification_report(y_test,predictions))
print('********')

print('Accuracy with Logistic Regression: ',accuracy_score(y_test,predictions))
print('********')
# Out:
# Classification report               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        63
#            1       0.98      1.00      0.99        47
#
#     accuracy                           0.99       110
#    macro avg       0.99      0.99      0.99       110
# weighted avg       0.99      0.99      0.99       110
#
# ********
# Accuracy with Logistic Regression:  0.990909090909091
# ********
